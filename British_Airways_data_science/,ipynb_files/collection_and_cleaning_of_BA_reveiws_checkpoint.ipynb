# %% [markdown]
# # Data Collection
#   - Web scrapping from the website [Skytrax](https://www.airlinequality.com/airline-reviews/british-airways), clean, and analysis.

# %%
# imports necessary modules

import os
import re
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import datetime as dt

from wordcloud import WordCloud, STOPWORDS

import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

# %%
# collect all reviews, ratings stars, date, reviewer country
reviews, stars, date, country  = [], [], [], []

# %%
for i in range(1, 36):
    page = requests.get(f"https://www.airlinequality.com/airline-reviews/british-airways/page/{i}/?sortby=post_date%3ADesc&pagesize=100")

    soup = BeautifulSoup(page.content, "html5")

    for item in soup.find_all("div", class_="text_content"):
        reviews.append(item.text)

    for item in soup.find_all("div", class_ = "rating-10"):
        try:
            stars.append(item.span.text)
        except:
            print(f"Error on page {i}")
            stars.append("None")

    #date
    for item in soup.find_all("time"):
        date.append(item.text)

    #country
    for item in soup.find_all("h3"):
        country.append(item.span.next_sibling.text.strip(" ()"))
# Out:
# Error on page 34
# Error on page 35
# Error on page 35

# %%
# total reviews extracted
len(reviews)
# Out:
# 3500

# %%
# total reviewer country
len(country)
# Out:
# 3500

# %%
# total star length
len(stars)
# Out:
# 3535

# %%
# total date
len(date)
# Out:
# 3500

# %%
# fix the length of stars
stars = stars[:3500]
len(stars)
# Out:
# 3500

# %%
#create  a dataframe from these collected lists of data
df = pd.DataFrame({"reviews":reviews,"stars": stars, "date":date, "country": country})

# %%
# first five rows
df.head()
# Out:
#                                              reviews  \
# 0  ✅ Trip Verified |   The seats were excellent, ...
# 1  ✅ Trip Verified |   After the nightmare of get...
# 2  ✅ Trip Verified |   Prior to boarding a gate a...
# 3  ✅ Trip Verified |   I flew from Amsterdam to L...
# 4  ✅ Trip Verified | First the good news, the clu...
#
#                          stars                date         country
# 0  \n\t\t\t\t\t\t\t\t\t\t\t\t5  28th February 2025  United Kingdom
# 1                            9  27th February 2025  United Kingdom
# 2                            5  21st February 2025  United Kingdom
# 3                            3  18th February 2025     Netherlands
# 4                            1  14th February 2025  United Kingdom

# %%
df.shape
# Out:
# (3500, 4)

# %%
# export the data in csv format
df.to_csv("data/BA_reviews.csv")

# %% [markdown]
# ## Data Cleaning

# %%
# import data
df = pd.read_csv("data/BA_reviews.csv", index_col=0)

# %%
df.head()
# Out:
#                                              reviews  stars  \
# 0  ✅ Trip Verified |   The seats were excellent, ...    5.0
# 1  ✅ Trip Verified |   After the nightmare of get...    9.0
# 2  ✅ Trip Verified |   Prior to boarding a gate a...    5.0
# 3  ✅ Trip Verified |   I flew from Amsterdam to L...    3.0
# 4  ✅ Trip Verified | First the good news, the clu...    1.0
#
#                  date         country
# 0  28th February 2025  United Kingdom
# 1  27th February 2025  United Kingdom
# 2  21st February 2025  United Kingdom
# 3  18th February 2025     Netherlands
# 4  14th February 2025  United Kingdom

# %%
# column which mentions if the user is verified or not
df['verified'] = df.reviews.str.contains("Trip Verified")

# %%
df['verified']
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 3495    False
# 3496    False
# 3497    False
# 3498    False
# 3499    False
# Name: verified, Length: 3500, dtype: bool

# %%
#extract the column of reviews into a separate dataframe and clean it for semantic analysis
#for lemmatization of words we will use nltk library
lemma = WordNetLemmatizer()
import nltk
nltk.download('stopwords')
# Download the 'wordnet' dataset
nltk.download('wordnet')


reviews_data = df.reviews.str.strip("✅ Trip Verified |")

#create an empty list to collect cleaned data corpus
corpus =[]

#loop through each review, remove punctuations, small case it, join it and add it to corpus
for rev in reviews_data:
    rev = re.sub('[^a-zA-Z]',' ', rev)
    rev = rev.lower()
    rev = rev.split()
    rev = [lemma.lemmatize(word) for word in rev if word not in set(stopwords.words("english"))]
    rev = " ".join(rev)
    corpus.append(rev)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
# add the corpus to the original dataframe
df['corpus'] = corpus

# %%
df.head()
# Out:
#                                              reviews  stars  \
# 0  ✅ Trip Verified |   The seats were excellent, ...    5.0
# 1  ✅ Trip Verified |   After the nightmare of get...    9.0
# 2  ✅ Trip Verified |   Prior to boarding a gate a...    5.0
# 3  ✅ Trip Verified |   I flew from Amsterdam to L...    3.0
# 4  ✅ Trip Verified | First the good news, the clu...    1.0
#
#                  date         country  verified  \
# 0  28th February 2025  United Kingdom      True
# 1  27th February 2025  United Kingdom      True
# 2  21st February 2025  United Kingdom      True
# 3  18th February 2025     Netherlands      True
# 4  14th February 2025  United Kingdom      True
#
#                                               corpus
# 0  seat excellent feel much room official seat pi...
# 1  nightmare getting triple security nairobi airp...
# 2  prior boarding gate agent seemed pick elderly ...
# 3  flew amsterdam la vega layover heathrow novemb...
# 4  first good news club suite huge improvement ol...

# %%
df.dtypes
# Out:
# reviews      object
# stars       float64
# date         object
# country      object
# verified       bool
# corpus       object
# dtype: object

# %%
# convert the date to datetime format
df.date = pd.to_datetime(df.date, format='mixed')

# %%
df.date.head()
# Out:
# 0   2025-02-28
# 1   2025-02-27
# 2   2025-02-21
# 3   2025-02-18
# 4   2025-02-14
# Name: date, dtype: datetime64[ns]

# %%
#check for unique ratings
df.stars.unique()
# Out:
# array([ 5.,  9.,  3.,  1.,  4.,  7.,  2.,  8., 10.,  6., nan])

# %%
# Convert the 'stars' column to string type before using .str accessor
df.stars = df.stars.astype(str).str.strip("\n\t\t\t\t\t\t\t\t\t\t\t\t\t")

# %%
df.stars.value_counts()
# Out:
# stars
# 1.0     893
# 2.0     407
# 3.0     402
# 8.0     335
# 10.0    280
# 7.0     271
# 9.0     265
# 5.0     245
# 4.0     234
# 6.0     167
# nan       1
# Name: count, dtype: int64

# %%
# drop the rows where the value of ratings is None
df.drop(df[df.stars == "None"].index, axis=0, inplace=True)

# %%
#check the unique values again
df.stars.unique()
# Out:
# array(['5.0', '9.0', '3.0', '1.0', '4.0', '7.0', '2.0', '8.0', '10.0',
#        '6.0', 'nan'], dtype=object)

# %%
# checking null value on all dataset
df.isnull().value_counts()
# Out:
# reviews  stars  date   country  verified  corpus
# False    False  False  False    False     False     3499
#                        True     False     False        1
# Name: count, dtype: int64

# %%
df.country.isnull().value_counts()
# Out:
# country
# False    3499
# True        1
# Name: count, dtype: int64

# %%
# drop the rows using index where the country value is null
df.drop(df[df.country.isnull() == True].index, axis=0, inplace=True)

# %%
df.shape
# Out:
# (3499, 6)

# %%
#resetting the index
df.reset_index(drop=True)
# Out:
#                                                 reviews stars       date  \
# 0     ✅ Trip Verified |   The seats were excellent, ...   5.0 2025-02-28
# 1     ✅ Trip Verified |   After the nightmare of get...   9.0 2025-02-27
# 2     ✅ Trip Verified |   Prior to boarding a gate a...   5.0 2025-02-21
# 3     ✅ Trip Verified |   I flew from Amsterdam to L...   3.0 2025-02-18
# 4     ✅ Trip Verified | First the good news, the clu...   1.0 2025-02-14
# ...                                                 ...   ...        ...
# 3494  On past experience I chose BA for our long hau...   9.0 2014-11-25
# 3495  BA16 Singapore to London. B777 World Traveller...  10.0 2014-11-20
# 3496  LHR-LCA in Club Europe. The First class lounge...  10.0 2014-11-20
# 3497  LHR – LAX Club World A380 return a week later ...   7.0 2014-11-20
# 3498  SFO-LHR-DXB and return DXB-LHR-DEN outbound in...   9.0 2014-11-20
#
#              country  verified  \
# 0     United Kingdom      True
# 1     United Kingdom      True
# 2     United Kingdom      True
# 3        Netherlands      True
# 4     United Kingdom      True
# ...              ...       ...
# 3494  United Kingdom     False
# 3495       Singapore     False
# 3496  United Kingdom     False
# 3497  United Kingdom     False
# 3498   United States     False
#
#                                                  corpus
# 0     seat excellent feel much room official seat pi...
# 1     nightmare getting triple security nairobi airp...
# 2     prior boarding gate agent seemed pick elderly ...
# 3     flew amsterdam la vega layover heathrow novemb...
# 4     first good news club suite huge improvement ol...
# ...                                                 ...
# 3494  past experience chose ba long haul return flig...
# 3495  ba singapore london b world traveller cabin on...
# 3496  lhr lca club europe first class lounge fairly ...
# 3497  lhr lax club world return week later lax lhr f...
# 3498  sfo lhr dxb return dxb lhr den outbound premiu...
#
# [3499 rows x 6 columns]

# %%
# export the cleaned data
df.to_csv("data/cleaned-BA-reviews.csv")
